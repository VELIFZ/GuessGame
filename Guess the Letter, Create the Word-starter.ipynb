# %% [markdown]
# **Create a Letter Guessing Game**
#
# Create a program that allows a user 7 chances to guess the correct word. If they do not guess the word after 7 tries, the player loses and the program will print the correct word. Otherwise, the play wins and the game.
#
# **How to build the program**
# * When you start the game, you will need to select a random word from a list of at least 10 words (You have full control over which words you want to use for you program). This will be your secret word. Your secret word will be represented in the program as a group of underscores. For as long as the word is, you should also have that many underscores.
#
# * Once the word is selected, your game will commence. Perform a Google search to figure out how to select a random word from a list using Python.<br>
# **Hint** There's package you can import into your application that does this for you.
#
# * The end user will have a total of 7 chances to guess the correct letter from the secret word. If the end user makes 7 incorrect guesses, the game will end.
#
# * As you guess the correct letters, the letters you have guess will then take place of the underscores that letter represents. <br>
# **For Example**: If your secret word is 'watermelon' and  so far you have guessed the letters 'a' and 'e', the word you're trying to guess will appear as follows: _ a _ e _ _ e _ _ _.<br>
# **Keep in mind** that if you guess a letter that appears more than once in your secret word, make sure that the letter is populated anywhere that letter would be.

# %%
print("""**********
Letter Guessing Game

Guess a word that is related with programming.

***********""")

import random

languages = ['ruby', 'react', 'c++', 'kotlin', 'php', 'matlab', 'swift', 'java', 'julia', 'scala'] #bu kismi file ile yap
#with open('etc') as file
language = random.choice(languages) # burada listeden bir tane item sececek

def game():
    guessed_letter = []
    for i in range(len(language)):
        guessed_letter.append("__")
    the_word = [i for i in guessed_letter]
    print(*([the_word]))
    the_word ="".join(the_word)
    
    max_guess = 7
    
    while max_guess > 0:
        if the_word == language:
                    print('Yay! You did it.')
                    break  
        guess = input("\nGuess a letter: ")
        max_guess -=1
        if guess in language:
            print(f'You found one letter, guess another one.')
            for i in range(len(language)):       
                if language[i] == guess:
                    guessed_letter[i] = language[i]
                    #print(guessed_letter)            
        else:
            print('Your guess is wrong! Try again.')
            print('='*10)
            print(f'You have {max_guess} more guess!')
        
        the_word = [i for i in guessed_letter]
        the_word ="".join(the_word)
        print(the_word)
        
    if max_guess == 0:
        print('*' * 15)
        print('Sorry! You reached 7 guess.')
    
    
game()
# Out:
# **********
# Letter Guessing Game
#
# Guess a word that is related with programming.
#
# ***********
# ['__', '__', '__', '__']
#
# Guess a letter: a
# Your guess is wrong! Try again.
# ==========
# You have 6 more guess!
# ________
#
# Guess a letter: r
# You found one letter, guess another one.
# r______
#
# Guess a letter: u
# You found one letter, guess another one.
# ru____
#
# Guess a letter: b
# You found one letter, guess another one.
# rub__
#
# Guess a letter: y
# You found one letter, guess another one.
# ruby
# Yay! You did it.

# %%
print("""**********
Letter Guessing Game

Guess a word that is related with programming.

***********""")

import random

languages = ['ruby', 'react', 'c++', 'kotlin', 'php', 'matlab', 'swift', 'java', 'julia', 'scala'] #bu kismi file ile yap
#with open('etc') as file
language = random.choice(languages) # burada listeden bir tane item sececek

guessed_letter = []
for i in range(len(language)):
    guessed_word.append("__")
the_word = [i for i in guessed_letter]
print(*(the_word))
the_word ="".join(the_word)

def letter_display():
        for i in range(len(language)):
            if language[i] == guess:
                guessed_letter[i] = language[i]
        #the_word = [i for i in guessed_letter]
        the_word ="".join(the_word)
        print(*(the_word))
        print(the_word)
        user_guess()
        
def user_guess():
    max_guess = 7
    #eger 7 denemeden az denemede bulunursa, yeni kelime secsin random
    while max_guess > 0:
        guess = input("\nGuess a letter: ").lower()
        max_guess -=1
        if guess in language:
            print(f'You found one letter, guess another one.')
            letter_display()
            max_guess -=1
            if guess == language:
                print('Yay! You did it.')
                letter_display()
                break
        else:
            print('Your guess is wrong! Try again.')
            print('='*10)
            print(f'You have {max_guess} more guess!')
    if max_guess == 0:
        letter_display()
        print('*' * 15)
        print('Sorry! You reached 7 guess.')
        


user_guess()
# Out:
# **********
# Letter Guessing Game
#
# Guess a word that is related with programming.
#
# ***********
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-b580e19f4bc9> in <module>
#      14 guessed_letter = []
#      15 for i in range(len(language)):
# ---> 16     guessed_word.append("__")
#      17 the_word = [i for i in guessed_letter]
#      18 print(*(the_word))
#
# NameError: name 'guessed_word' is not defined
